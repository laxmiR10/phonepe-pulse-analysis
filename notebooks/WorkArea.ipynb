# %%
# !pip install matplotlib seaborn
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp313-cp313-win_amd64.whl.metadata (52 kB)
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.61.1-cp313-cp313-win_amd64.whl.metadata (116 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp313-cp313-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in d:\lakshmi\python\lib\site-packages (from matplotlib) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in d:\lakshmi\python\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in d:\lakshmi\python\lib\site-packages (from matplotlib) (12.0.0)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in d:\lakshmi\python\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in d:\lakshmi\python\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: pytz>=2020.1 in d:\lakshmi\python\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\lakshmi\python\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\lakshmi\python\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.8-cp313-cp313-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.1 MB 1.7 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.0/8.1 MB 1.5 MB/s eta 0:00:05
#    ------ --------------------------------- 1.3/8.1 MB 1.5 MB/s eta 0:00:05
#    ------- -------------------------------- 1.6/8.1 MB 1.5 MB/s eta 0:00:05
#    ----------- ---------------------------- 2.4/8.1 MB 1.7 MB/s eta 0:00:04
#    ------------ --------------------------- 2.6/8.1 MB 1.7 MB/s eta 0:00:04
#    -------------- ------------------------- 2.9/8.1 MB 1.7 MB/s eta 0:00:04
#    ---------------- ----------------------- 3.4/8.1 MB 1.7 MB/s eta 0:00:03
#    ------------------- -------------------- 3.9/8.1 MB 1.8 MB/s eta 0:00:03
#    -------------------- ------------------- 4.2/8.1 MB 1.8 MB/s eta 0:00:03
#    ------------------------ --------------- 5.0/8.1 MB 1.8 MB/s eta 0:00:02
#    ------------------------- -------------- 5.2/8.1 MB 1.8 MB/s eta 0:00:02
#    ------------------------- -------------- 5.2/8.1 MB 1.8 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.8/8.1 MB 1.7 MB/s eta 0:00:02
#    ----------------------------- ---------- 6.0/8.1 MB 1.7 MB/s eta 0:00:02
#    ------------------------------ --------- 6.3/8.1 MB 1.7 MB/s eta 0:00:02
#    --------------------------------- ------ 6.8/8.1 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.1/8.1 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.1 MB 1.7 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.1 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 1.7 MB/s  0:00:04
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl (226 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp313-cp313-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB 1.4 MB/s eta 0:00:02
#    ------------------ --------------------- 1.0/2.3 MB 1.4 MB/s eta 0:00:01
#    --------------------------- ------------ 1.6/2.3 MB 1.5 MB/s eta 0:00:01
#    ------------------------------- -------- 1.8/2.3 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------ --- 2.1/2.3 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 1.5 MB/s  0:00:01
# Downloading kiwisolver-1.4.9-cp313-cp313-win_amd64.whl (73 kB)
# Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
#
#    ---------------------------------------- 0/7 [pyparsing]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ---------------------- ----------------- 4/7 [contourpy]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [seaborn]
#    ---------------------------------- ----- 6/7 [seaborn]
#    ---------------------------------- ----- 6/7 [seaborn]
#    ---------------------------------------- 7/7 [seaborn]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 kiwisolver-1.4.9 matplotlib-3.10.8 pyparsing-3.2.5 seaborn-0.13.2

# %%
states = pd.read_sql(
    "SELECT DISTINCT state FROM map_transaction",
    engine
)["state"]

available = [s for s in states if is_district_map_available(s)]
unavailable = [s for s in states if s not in available]

st.write("Available district maps:", available)
st.write("Unavailable district maps:", unavailable)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 states = pd.read_sql(
#       2     "SELECT DISTINCT state FROM map_transaction",
#       3     engine
#       4 )["state"]
#       6 available = [s for s in states if is_district_map_available(s)]
#       7 unavailable = [s for s in states if s not in available]
#
# NameError: name 'pd' is not defined
